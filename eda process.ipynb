# %%
import pandas as pd
import numpy as np

dataset = pd.read_csv('data.csv')

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 356 entries, 0 to 355
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           356 non-null    int64
#  1   name         356 non-null    object
#  2   group        356 non-null    object
#  3   section      355 non-null    object
#  4   provisional  12 non-null     object
#  5   country      356 non-null    object
#  6   url          356 non-null    object
#  7   image        245 non-null    object
#  8   pdf          355 non-null    object
# dtypes: int64(1), object(8)
# memory usage: 25.2+ KB

# %%
dataset.describe()
# Out:
#                id
# count  356.000000
# mean   187.910112
# std    106.667908
# min      1.000000
# 25%     96.750000
# 50%    188.500000
# 75%    281.250000
# max    370.000000

# %%
dataset.describe(include='object')
# Out:
#                    name                            group       section  \
# count               356                              356           355
# unique              356                               10            38
# top     ENGLISH POINTER  Scent hounds and related breeds  Scent hounds
# freq                  1                               72            67
#
#        provisional        country  \
# count           12            356
# unique           9             64
# top       9/4/2019  GREAT BRITAIN
# freq             3             57
#
#                                                       url  \
# count                                                 356
# unique                                                356
# top     https://www.fci.be/en/nomenclature/ENGLISH-POI...
# freq                                                    1
#
#                                                     image  \
# count                                                 245
# unique                                                245
# top     https://www.fci.be/Nomenclature/Illustrations/...
# freq                                                    1
#
#                                                       pdf
# count                                                 355
# unique                                                355
# top     https://www.fci.be/Nomenclature/Standards/001g...
# freq                                                    1

# %%
duplicateRows = dataset[dataset.duplicated()]

# %%
duplicateRows
# Out:
# Empty DataFrame
# Columns: [id, name, group, section, provisional, country, url, image, pdf]
# Index: []

# %%
for i in range(0,dataset.shape[0]):
    dataset
    dataset

# %%
dataset.isna().any()
# Out:
# id             False
# name           False
# group          False
# section         True
# provisional     True
# country        False
# url            False
# image           True
# pdf             True
# dtype: bool

# %%
dataset.isnull().sum()
# Out:
# id               0
# name             0
# group            0
# section          1
# provisional    344
# country          0
# url              0
# image          111
# pdf              1
# dtype: int64

# %%
dataset.describe()
# Out:
#                id
# count  356.000000
# mean   187.910112
# std    106.667908
# min      1.000000
# 25%     96.750000
# 50%    188.500000
# 75%    281.250000
# max    370.000000
